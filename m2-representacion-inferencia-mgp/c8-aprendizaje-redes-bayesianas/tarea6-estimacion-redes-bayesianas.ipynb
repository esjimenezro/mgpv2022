# %% [markdown]
# # Estimación de parámetros en redes Bayesianas
#
# <img style="float: right; margin: 0px 0px 15px 15px;" src="https://upload.wikimedia.org/wikipedia/commons/d/d5/Hey_Machine_Learning_Logo.png" width="400px" height="400px" />
#
# > En esta sexta y última tarea, obtendrás aplicaras los principios de estimación de parámetros vistos en clases sobre el ejemplo de las flores (o alguno que te interese).
#
# <p style="text-align:right;"> Imagen recuperada de: https://upload.wikimedia.org/wikipedia/commons/d/d5/Hey_Machine_Learning_Logo.png.</p>
#
# ___

# %% [markdown]
# ## Estimación en redes Bayesianas

# %% [markdown]
# El archivo `flower_model_samples.csv` contiene datos del siguiente modelo:

# %%
from IPython.display import Image

# %%
Image("figures/iris.png")

# %% [markdown]
# 1. Estimar los parámetros usando máxima verosimilitud.

# %% [markdown]
# 2. Estimar los parámetros usando MAP con previa de Dirichlet, con pseudo-counts iguales (equivalent sample size d $\alpha=1, 10, 100, 1000$) para todas las asignaciones posibles de las CPDs.

# %% [markdown]
# 3. Para un conjunto de pruebas, prediga la variable Type (T) con cada uno de los parámetros ajustados en los puntos 1 y 2.
#
#   - ¿Cuál modelo tiene mejores resultados?

# %% [markdown]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#808080; background:#fff;">
# Created with Jupyter by Esteban Jiménez Rodríguez.
# </footer>
