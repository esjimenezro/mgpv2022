# %% [markdown]
# # Tarea 5. Inferencia en redes Bayesianas.
#
# <img style="float: right; margin: 0px 0px 15px 15px;" src="https://upload.wikimedia.org/wikipedia/commons/1/18/Bayes%27_Theorem_MMB_01.jpg" width="400px" height="300px" />
#
# En esta tarea vas a usar los algoritmos de inferencia vistos en clase para inferir algunas probabilidades interesantes en nuestro ejemplo del estudiante.
#
# <p style="text-align:right;"> Imagen recuperada de: https://upload.wikimedia.org/wikipedia/commons/1/18/Bayes%27_Theorem_MMB_01.jpg.</p>
#
# ___

# %% [markdown]
# # 1. Inferencia sobre la red del estudiante
#
# Para el ejemplo del estudiante lleve a cabo las siguientes ifnerencias usando el algoritmo de eliminación de variables de `pgmpy`.

# %%
from IPython.display import Image

# %%
Image(filename='figures/Student1.png')

# %% [markdown]
# **1. Causal**
#
# $$P(r^1)$$
#
# $$P(r^1 | i^0)$$
#
# $$P(r^1 | i^0, d^0)$$

# %% [markdown]
# **2. Evidencial**
#
# $$P(d^1)$$
#
# $$P(d^1 | c^0)$$
#
# $$P(i^1)$$
#
# $$P(i^1 | c^0)$$

# %% [markdown]
# **3. Intercausal**
#
# $$P(i^1)$$
#
# $$P(i^1 | c^0)$$
#
# $$P(i^1 | c^0, d^1)$$

# %% [markdown]
# # 2. Inferencia sobre la red del estudiante
#
# Infiera las probabilidades del punto 1 usando inferencia aproximada, con un nivel de error $\epsilon=0.01$ y con un nivel de confianza $1 - \delta = 0.9$.

# %% [markdown]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#808080; background:#fff;">
# Created with Jupyter by Esteban Jiménez Rodríguez.
# </footer>
